# %% [markdown]
# <a href="https://colab.research.google.com/github/gkw314/oz_assignment/blob/main/Ch14_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <span style="font-size:100%">
#
# 수업은 모두 열심히 들으셨나요?
#
# 간혹 강의에서 언급되지 않은 내용이 문제로 나올 수 있습니다.<br>
# 그럴땐 강의 내용 외 문제는 구글링을 통해 해결해주세요<br></span>
# <span style="font-size:80%">
# (구글링 또한 개발자가 갖쳐야할 역량 중에 하나랍니다 😊)
# </span>
#
# ---

# %% [markdown]
# <span style="font-size:80%">[문제1]<br><br></span>
# ```다음 중 True로 취급되지 않는 것을 골라주세요```
#
# 1. 1
# 2. "수강생"
# 3. None
# 4. ["양파", "옥수수", "배추"]

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 3번

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제2]<br><br></span>
# ```아래 코드의 출력 결과를 입력해주세요```
#
# ```if not ' ':```<br>
# &nbsp;```  print(True)```<br>
#
# ```else:```<br>
# &nbsp;```  print(False)```<br>

# %% [markdown]
# <span style="color:red">답변</span>

# %%
if not ' ':
 print(True)

else:
 print(False)
# Out:
# False

# %% [markdown]
# False

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제3]<br><br></span>
# ```if 조건문에 대한 설명으로 올바른 것을 골라주세요```
#
# 1. if문은 조건을 만족하지 않을때 실행된다.
# 2. else문은 조건문이 참일 때 실행된다.
# 3. else는 단독으로 사용할 수 없다.
# 4. else에서 실행되는 코드는 다음 줄에서 들여쓰기를 하지 않아야 한다.
# 5. if는 항상 else가 있어여 한다.

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 3번

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제4]<br><br></span>
# ```아래 코드의 출력으로 올바른 것을 골라주세요```
#
# ```x = 5```
#
# ```if x % 2 ==0:```<br>
# &nbsp;&nbsp;```print("짝수")```
#
# ```else:```<br>
# &nbsp;&nbsp;```print("홀수")```<br>
#
#
# 1. 짝수
# 2. 1
# 3. 2
# 4. 홀수
# 5. 아무것도 출력되지 않는다.

# %% [markdown]
# <span style="color:red">답변</span>

# %%
x = 5

if x % 2 ==0:
  print("짝수")

else:
  print("홀수")
# Out:
# 홀수

# %% [markdown]
# 4번.
#
# ```
# # 코드로 형식 지정됨
# if x % 2 ==0:
# ```
# 이게 약간 홀짝 찾는거...공식
#    걍 자주나오니 아몰라 외워

# %% [markdown]
# ----

# %% [markdown]
# <span style="font-size:80%">[문제5]<br><br></span>
# ```아래의 if 조건과 동일한 조건을 찾아주세요```
#
# ```if 15 >= x and x > 3```
#
# 1. x < 3 < 15
# 2. 3 <= x < 15
# 3. 3 <= x <= 15
# 4. 15 >= x
# 5. 3 < x <= 15

# %% [markdown]
# <span style="color:red">답변</span>

# %% [markdown]
# 5번
